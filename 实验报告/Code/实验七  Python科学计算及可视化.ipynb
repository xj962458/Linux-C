# %% [markdown]
# 1.	分别用列表和numpy中array随机生成十万个数，统计其平方和，并比较两种方法的运行时间。

# %%
import time
import numpy as np
import random

# 列表随机生成
start = time.perf_counter()
a = [random.randint(0, 101) for i in range(100000)]
x = 0
for i in a:
    x += i*i
print("随机矩阵元素的平方和为:", x)
end = time.perf_counter()
print("列表用时{:5f}s".format(end-start))

# numpy库随机生成
start = time.perf_counter()
a = np.random.randint(0, 101, 100000)
a = np.square(a)
print("随机矩阵元素的平方和为:", a.sum())
end = time.perf_counter()
print("numpy用时{:5f}s".format(end-start))
# Out:
# 随机矩阵元素的平方和为: 340787300
# 列表用时0.069855s
# 随机矩阵元素的平方和为: 334646388
# numpy用时0.002273s

# %% [markdown]
# 2.	利用numpy随机函数生成一个4行5列数值是（100,200）随机整数的矩阵。对矩阵中的数分别求平方根，平方，取整；使用numpy的统计函数：Sum,mean ,average,std,var，min,max等函数。

# %%
import numpy as np

a = np.random.randint(100, 201, 20).reshape(4, 5) #生成4行5列数值是(100,200)随机整数矩阵

print('初始矩阵：\n',a)    # 输出矩阵
print('平方根：\n',np.sqrt(a))   # 平方根
print('平方：\n',np.square(a))  # 平方
print('向上取整：\n',np.ceil(a))  # 向上取整
print('向下取整：\n',np.floor(a))  # 向下取整

print('求和：\n',a.sum())  # 求和
print('平均值：\n',a.mean())  # 平均值
print('平均值：\n',np.average(a))  # 平均值
print('方差：\n',a.std())  # 方差
print('标准差：\n',a.var())  # 标准差
print('最小值：\n',a.min())  # 最小值
print('最大值：\n',a.max())  # 最大值
# Out:
# 初始矩阵：
#  [[195 157 194 122 109]
#  [129 190 193 190 141]
#  [173 163 169 126 156]
#  [165 127 110 103 100]]
# 平方根：
#  [[13.96424004 12.52996409 13.92838828 11.04536102 10.44030651]
#  [11.35781669 13.78404875 13.89244399 13.78404875 11.87434209]
#  [13.15294644 12.76714533 13.         11.22497216 12.489996  ]
#  [12.84523258 11.26942767 10.48808848 10.14889157 10.        ]]
# 平方：
#  [[38025 24649 37636 14884 11881]
#  [16641 36100 37249 36100 19881]
#  [29929 26569 28561 15876 24336]
#  [27225 16129 12100 10609 10000]]
# 向上取整：
#  [[195. 157. 194. 122. 109.]
#  [129. 190. 193. 190. 141.]
#  [173. 163. 169. 126. 156.]
#  [165. 127. 110. 103. 100.]]
# 向下取整：
#  [[195. 157. 194. 122. 109.]
#  [129. 190. 193. 190. 141.]
#  [173. 163. 169. 126. 156.]
#  [165. 127. 110. 103. 100.]]
# 求和：
#  3012
# 平均值：
#  150.6
# 平均值：
#  150.6
# 方差：
#  32.22793819033417
# 标准差：
#  1038.6399999999999
# 最小值：
#  100
# 最大值：
#  195

# %% [markdown]
# 3.	在同一坐标轴中绘制下列函数曲线:Y=2X2(红色虚线), Y=3X3(蓝色虚点画线), Y=4X4(黄色虚破折线)并分别在X轴和Y轴标上中文标签(“X轴. Y轴“)，并加上标题“函数曲线”

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

x = np.linspace(-2, 2)
y1 = 2*np.power(x, 2)
y2 = 3*np.power(x, 3)
y3 = 4*np.power(x, 4)
matplotlib.rcParams['font.family'] = 'KaiTi'  # 显示中文字符
matplotlib.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.figure()
plt.title('函数曲线', fontsize=25)  # 设置标题
plt.xlabel('X轴', fontsize=15)  # 设置x轴标签
plt.ylabel('Y轴', fontsize=15)  # 设置y轴标签
plt.plot(x, y1, 'r:', label='$y=2x^2$')
plt.plot(x, y2, 'b-.', label='$y=3x^3$')
plt.plot(x, y3, 'y--', label='$y=4x^4$')
plt.legend(loc=0)  # 放置图注位置为中间
plt.show()

# %% [markdown]
# 4.编码实现下列三个函数图形：
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 1000)
y = np.cos(2*np.pi*x)
matplotlib.rcParams['font.family'] = 'KaiTi'  # 显示中文字符
matplotlib.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.grid()  # 设置网格线
plt.xlim(-1, 6)  # 设置x轴取值范围
plt.ylim(-2.0, 2.0)  # 设置y轴取值范围
plt.plot(x, y, 'r--')
plt.title('正弦波实例$y=cos(2Πx)$', fontsize=25)  # 设置图表标题
plt.xlabel('横轴：时间', fontsize=15, color='red')  # 设置x轴标签
plt.ylabel('纵轴:振幅', fontsize=15, color='black')  # 设置y轴标签
plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 6.27, 200)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x*x)
for i in [[221, y1, 'r'], [222, y2, 'b--'], [212, y3, 'g--']]:
    plt.subplot(i[0])
    plt.plot(x, i[1], i[2])
    plt.xticks(np.arange(0, 8))
    plt.yticks(np.arange(-1.0, 1.5, 0.5))
plt.show()

# %% [markdown]
# ## 思考题

# %% [markdown]
# 1.numpy中的统计函数有哪些？各有什么用途？
#     答：np.max():找出最大值;np.min():找出最小值;np.sum():计算所有元素之和;np.prod():计算数组中所有元素之积;np.std():计算元素的标准差;np.var():计算元素的方差;np.mean():计算元素的平均值;np.median():计算元素的中位数等很多函数。

# %% [markdown]
# 2.在百度上爬取一副图片存到E:\下，利用numpy将其转换为数组im0对象并进行如下操作并显示：（1）转换为黑白图像；（2）反变换255-im0（3）区间变换：（100/255）*im0+150；(4)像素平方处理255*（im1/255）**2

# %%
import requests
from PIL import Image
import numpy as np

r = requests.get('https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1607964223342&di=ff99345abf401179205f0125d116d772&imgtype=0&src=http%3A%2F%2F5b0988e595225.cdn.sohucs.com%2Fimages%2F20190217%2F74b027cd90f24603943bad768f65247d.jpeg', timeout=30)
with open('./test.jpg', 'wb') as f:
    f.write(r.content)


im0 = np.array(Image.open('./test.jpg').convert('L'))  # 转化为黑白图像
im1 = 255-im0  # 反变换
im2 = (100/255)*im0+150  # 区间变换
im3 = 255*(im1/255)**2  # 像素平方处理
for i in [im0, im1, im2, im3]:  # 显示图像
    pil_im = Image.fromarray(np.uint(i))
    pil_im.show()

# %% [markdown]
# 3.ndarray的降维是什么含义？如何降维？
#     答：ndarray的降维是将多维数组转变为低维数组。常见的降维方法有np.reshape()、np.resize()、np.swapaxes()和np.flatten()等。

# %% [markdown]
# 4.Pyplot中有哪些基本的绘图函数和操作?
# 答：有绘制二维曲线的plot()函数，有绘制柱状图的bar()函数，有绘制散点图的scatter()函数,有绘制条形图的barh()函数,有绘制直方图的hist()函数，有绘制饼图的pie()函数，有绘制极线图的polar()函数等。
